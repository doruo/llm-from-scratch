# %%
file_name = "data/journey_to_the_center_of_the_earth.txt"
f = open(file_name, encoding="utf8")

text = f.read()
vocabulary = sorted(set(text))

def string_to_int(chars): 
   return { char:i for i, char in enumerate(chars) }

def int_to_string(chars):
   return { i:char for i, char in enumerate(chars) }

# Not working
def encode(chars):
   return { string_to_int(c) for c in chars }

print (encode(text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      13 def encode(chars):
#      14    return { string_to_int(c) for c in chars }
# ---> 16 print (encode(text))
#
# Cell In[4], line 14, in encode(chars)
#      13 def encode(chars):
# ---> 14    return { string_to_int(c) for c in chars }
#
# TypeError: unhashable type: 'dict'
